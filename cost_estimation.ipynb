# %%
import numpy as np
import pandas as pd

cost_data = pd.read_csv("data/funds.csv", parse_dates=['date'])
ref_data = pd.read_csv("data/refugee_monthly.csv")

col = 'Value'
ref_data[col] = pd.to_numeric(ref_data[col], errors='coerce')
ref_data[col] = ref_data[col].fillna(2)

month_mapping = {'January':1, 'February':2, 'April':3, 'May':4, 'July':5, 'August':6,'September':7, 'October':8, 'November':9, 'June':10, 'March':11, 'December': 12}
ref_data.Month = ref_data.Month.map(month_mapping)

ref_data_agg = ref_data.groupby(['Year', 'Month', 'Country / territory of asylum/residence'], as_index=False)["Value"].sum()
ref_data_agg
# Out:
# /home/shivam/anaconda3/envs/fastai-cpu/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       Year  Month            Country / territory of asylum/residence    Value
# 0     1999      1                                          Australia    574.0
# 1     1999      1                                            Austria   1366.0
# 2     1999      1                                            Belgium   1956.0
# 3     1999      1                                           Bulgaria     81.0
# 4     1999      1                                             Canada   2209.0
# 5     1999      1                                         Czech Rep.    602.0
# 6     1999      1                                            Denmark    675.0
# 7     1999      1                                            Finland    101.0
# 8     1999      1                                             France   1760.0
# 9     1999      1                                            Germany   8216.0
# 10    1999      1                                             Greece    167.0
# 11    1999      1                                            Hungary    907.0
# 12    1999      1                                            Ireland    234.0
# 13    1999      1                                      Liechtenstein     73.0
# 14    1999      1                                         Luxembourg    241.0
# 15    1999      1                                        Netherlands   3556.0
# 16    1999      1                                             Norway    548.0
# 17    1999      1                                             Poland    226.0
# 18    1999      1                                           Portugal     34.0
# 19    1999      1                                            Romania     21.0
# 20    1999      1                                           Slovakia     54.0
# 21    1999      1                                           Slovenia     40.0
# 22    1999      1                                              Spain    664.0
# 23    1999      1                                             Sweden    942.0
# 24    1999      1                                        Switzerland   3953.0
# 25    1999      1                                             Turkey    514.0
# 26    1999      1                                         USA (EOIR)    863.0
# 27    1999      1  United Kingdom of Great Britain and Northern I...   4710.0
# 28    1999      2                                          Australia    681.0
# 29    1999      2                                            Austria   1150.0
# ...    ...    ...                                                ...      ...
# 8804  2017     11                                         Czech Rep.     92.0
# 8805  2017     11                                            Denmark    272.0
# 8806  2017     11                                            Estonia     10.0
# 8807  2017     11                                             France   8013.0
# 8808  2017     11                                            Germany  18078.0
# 8809  2017     11                                            Iceland     92.0
# 8810  2017     11                                            Ireland    209.0
# 8811  2017     11                                              Italy  13517.0
# 8812  2017     11                                              Japan   1462.0
# 8813  2017     11                                             Latvia     61.0
# 8814  2017     11                                          Lithuania     35.0
# 8815  2017     11                                         Luxembourg    223.0
# 8816  2017     11                                              Malta    161.0
# 8817  2017     11                                         Montenegro     38.0
# 8818  2017     11                                        Netherlands   1217.0
# 8819  2017     11                                        New Zealand     49.0
# 8820  2017     11                                             Norway    396.0
# 8821  2017     11                                             Poland    324.0
# 8822  2017     11                                      Rep. of Korea    786.0
# 8823  2017     11                                            Romania    402.0
# 8824  2017     11               Serbia and Kosovo: S/RES/1244 (1999)     25.0
# 8825  2017     11                                           Slovakia     18.0
# 8826  2017     11                                           Slovenia    130.0
# 8827  2017     11                                              Spain   2525.0
# 8828  2017     11                                             Sweden   1536.0
# 8829  2017     11                                        Switzerland   1501.0
# 8830  2017     11              The former Yugoslav Rep. of Macedonia     24.0
# 8831  2017     11                                             Turkey   9504.0
# 8832  2017     11                                      USA (INS/DHS)  16403.0
# 8833  2017     11  United Kingdom of Great Britain and Northern I...   3160.0
#
# [8834 rows x 4 columns]

# %%
year_agg = cost_data.groupby([cost_data.date.dt.year, 'recipient', 'category']).sum().reset_index()
summer = year_agg.groupby(['date', 'recipient'])['transaction_value'].transform('sum')
year_agg['distribution'] = year_agg['transaction_value']/summer
year_agg
# Out:
#       date                              recipient        category  \
# 0     1999                                   Mali       Education
# 1     1999                                   Mali  Infrastructure
# 2     1999                                Nigeria       Education
# 3     1999                                 Uganda       Education
# 4     2000                                Algeria       Education
# 5     2000                                Algeria   Emergency aid
# 6     2000                             Bangladesh       Education
# 7     2000                             Bangladesh  Infrastructure
# 8     2000                             Bangladesh           Other
# 9     2000                                  Benin  Infrastructure
# 10    2000                           Burkina Faso  Infrastructure
# 11    2000  Congo, The Democratic Republic Of The       Education
# 12    2000  Congo, The Democratic Republic Of The   Emergency aid
# 13    2000                         CãTe D'Ivoire  Infrastructure
# 14    2000                          Guinea-Bissau  Infrastructure
# 15    2000                                   Iraq   Emergency aid
# 16    2000                                Lebanon       Education
# 17    2000                 Libyan Arab Jamahiriya     Agriculture
# 18    2000                                   Mali       Education
# 19    2000                                   Mali     Environment
# 20    2000                                   Mali  Infrastructure
# 21    2000                                   Mali           Other
# 22    2000                                  Niger  Infrastructure
# 23    2000                                Nigeria       Education
# 24    2000                                Nigeria           Other
# 25    2000                                Senegal  Infrastructure
# 26    2000                                Somalia   Emergency aid
# 27    2000                                  Sudan       Education
# 28    2000                                  Sudan   Emergency aid
# 29    2000                                  Sudan     Environment
# ...    ...                                    ...             ...
# 5740  2018                                 Uganda   Emergency aid
# 5741  2018                                 Uganda     Environment
# 5742  2018                                 Uganda     General aid
# 5743  2018                                 Uganda  Infrastructure
# 5744  2018                                 Uganda           Other
# 5745  2018                                Ukraine       Education
# 5746  2018                                Ukraine   Emergency aid
# 5747  2018                         United Kingdom     Agriculture
# 5748  2018                         United Kingdom       Education
# 5749  2018                         United Kingdom     Environment
# 5750  2018                         United Kingdom           Other
# 5751  2018                          United States     Agriculture
# 5752  2018                          United States       Education
# 5753  2018                             Uzbekistan       Education
# 5754  2018      Venezuela, Bolivarian Republic Of       Education
# 5755  2018                               Viet Nam     Agriculture
# 5756  2018                               Viet Nam       Education
# 5757  2018                               Viet Nam     Environment
# 5758  2018                               Viet Nam  Infrastructure
# 5759  2018                         Western Sahara       Education
# 5760  2018                                  Yemen       Education
# 5761  2018                                  Yemen   Emergency aid
# 5762  2018                                 Zambia     Agriculture
# 5763  2018                                 Zambia       Education
# 5764  2018                                 Zambia     Environment
# 5765  2018                                 Zambia     General aid
# 5766  2018                                 Zambia  Infrastructure
# 5767  2018                               Zimbabwe     Agriculture
# 5768  2018                               Zimbabwe       Education
# 5769  2018                               Zimbabwe     Environment
#
#       transaction_value  distribution
# 0          4.514489e+07      0.778511
# 1          1.284388e+07      0.221489
# 2          5.708721e+07      1.000000
# 3          3.100000e+07      1.000000
# 4          2.391983e+08      0.997630
# 5          5.681313e+05      0.002370
# 6          2.934926e+08      0.967080
# 7          9.961978e+06      0.032825
# 8          2.876307e+04      0.000095
# 9          2.453299e+07      1.000000
# 10         2.453299e+07      1.000000
# 11         8.895092e+05      0.425541
# 12         1.200795e+06      0.574459
# 13         2.453299e+07      1.000000
# 14         2.453299e+07      1.000000
# 15         4.502580e+06      1.000000
# 16         3.273148e+08      1.000000
# 17         4.062119e+06      1.000000
# 18         4.760506e+08      0.947050
# 19         2.000000e+06      0.003979
# 20         2.453299e+07      0.048806
# 21         8.295511e+04      0.000165
# 22         2.453299e+07      1.000000
# 23         7.857948e+08      0.999789
# 24         1.660070e+05      0.000211
# 25         2.453299e+07      1.000000
# 26         3.056568e+05      1.000000
# 27         7.586839e+04      0.004315
# 28         2.085270e+06      0.118596
# 29         1.542187e+07      0.877089
# ...                 ...           ...
# 5740       2.390302e+08      0.042175
# 5741       5.119996e+08      0.090339
# 5742       2.429919e+08      0.042874
# 5743       1.229949e+08      0.021702
# 5744       2.774345e+07      0.004895
# 5745       2.630823e+07      0.935110
# 5746       1.825594e+06      0.064890
# 5747       4.937275e+06      0.081718
# 5748       5.454691e+07      0.902821
# 5749       2.129410e+03      0.000035
# 5750       9.320055e+05      0.015426
# 5751       4.745882e+06      0.524817
# 5752       4.297040e+06      0.475183
# 5753       1.156827e+06      1.000000
# 5754       4.551651e+06      1.000000
# 5755       8.618870e+05      0.012693
# 5756       3.273200e+07      0.482061
# 5757       2.179754e+07      0.321023
# 5758       1.250876e+07      0.184223
# 5759       5.251760e+05      1.000000
# 5760       1.156827e+06      0.036066
# 5761       3.091837e+07      0.963934
# 5762       4.416582e+07      0.183114
# 5763       1.764905e+08      0.731740
# 5764       1.653222e+07      0.068544
# 5765      -4.046621e+03     -0.000017
# 5766       4.008321e+06      0.016619
# 5767       1.710247e+07      0.093664
# 5768       1.599326e+08      0.875890
# 5769       5.559293e+06      0.030446
#
# [5770 rows x 5 columns]

# %%
# uc = list(year_agg.recipient.unique())
# ur = list(result_data.Country.unique())
# print(set((uc+ur)) - (set(uc) & set(ur)))
# sorted(ur)
# # print(uc)
# Out:
# {'Liberia', 'Zambia', 'Swaziland', 'Gabon', 'Togo', 'Bolivia, Plurinational State Of', 'Kenya', 'Ecuador', 'Kosovo', 'Central African Republic', 'Dominica', 'Argentina', 'South Africa', 'Equatorial Guinea', 'Egypt', 'Guinea-Bissau', 'Jamaica', 'Western Sahara', 'Cape Verde', 'Cameroon', 'Mexico', 'Indonesia', 'Iraq', 'Syrian Arab Republic', 'Bangladesh', 'Guyana', 'Eritrea', 'Luxembourg', 'USA (INS/DHS)', "Lao People'S Democratic Republic", 'Grenada', 'Tuvalu', 'Mauritius', 'Serbia', 'Cuba', 'Saint Kitts And Nevis', 'Morocco', 'Guinea', 'United Kingdom of Great Britain and Northern Ireland', 'Serbia and Kosovo: S/RES/1244 (1999)', 'South Sudan', 'Uganda', 'Chile', 'Sierra Leone', 'Czech Rep.', 'Thailand', 'Suriname', 'Nepal', 'Haiti', 'Russian Federation', 'Tunisia', 'Nigeria', 'Marshall Islands', 'Tajikistan', 'Congo, The Democratic Republic Of The', 'Ghana', 'United States', 'Sao Tome And Principe', 'Uzbekistan', 'Saint Vincent And The Grenadines', 'Dominican Republic', 'Mongolia', 'Namibia', 'Papua New Guinea', 'Niger', 'Myanmar', 'Ukraine', 'Bhutan', 'Kiribati', 'Antigua And Barbuda', 'Jordan', 'United Kingdom', 'Mozambique', 'Sri Lanka', 'Angola', 'Belize', 'Colombia', 'Yemen', 'Djibouti', 'Viet Nam', 'Nauru', 'Israel', 'Malta', 'Nicaragua', 'Guatemala', 'Bosnia and Herzegovina', 'Congo', 'Paraguay', 'Tanzania, United Republic Of', 'Algeria', 'Venezuela, Bolivarian Republic Of', 'Benin', 'China', 'Fiji', 'Samoa', 'Senegal', 'Korea, Republic Of', 'Bosnia And Herzegovina', 'Chad', 'Zimbabwe', 'Malaysia', 'Rwanda', 'Costa Rica', 'Libyan Arab Jamahiriya', 'Ethiopia', 'Peru', "Korea, Democratic People'S Republic Of", 'Georgia', 'Trinidad And Tobago', 'Somalia', 'Botswana', 'Macedonia, The Former Yugoslav Republic Of', 'USA (EOIR)', 'Panama', 'Iceland', 'Mauritania', 'Vanuatu', 'Malawi', 'Uruguay', 'Barbados', 'Philippines', 'Tonga', 'Liechtenstein', 'Honduras', 'Gambia', 'United Arab Emirates', 'Finland', 'Brazil', 'El Salvador', 'Mali', 'India', 'Moldova, Republic Of', 'Madagascar', 'Lebanon', 'Azerbaijan', 'Afghanistan', 'Comoros', 'Qatar', 'Burkina Faso', 'Maldives', 'Cambodia', 'Burundi', 'Rep. of Korea', 'Ireland', 'Kyrgyzstan', 'The former Yugoslav Rep. of Macedonia', 'Belarus', 'Kazakhstan', 'Timor-Leste', 'Estonia', "Cã\x94Te D'Ivoire", 'Solomon Islands', 'Saint Lucia', 'Lesotho', 'Pakistan', 'Palestinian Territory, Occupied', 'Sudan', 'Seychelles', 'Latvia', 'Armenia', 'Iran, Islamic Republic Of'}
# ['Albania',
#  'Australia',
#  'Austria',
#  'Belgium',
#  'Bosnia and Herzegovina',
#  'Bulgaria',
#  'Canada',
#  'Croatia',
#  'Cyprus',
#  'Czech Rep.',
#  'Denmark',
#  'Estonia',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'Iceland',
#  'Ireland',
#  'Italy',
#  'Japan',
#  'Latvia',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Malta',
#  'Montenegro',
#  'Netherlands',
#  'New Zealand',
#  'Norway',
#  'Poland',
#  'Portugal',
#  'Rep. of Korea',
#  'Romania',
#  'Serbia and Kosovo: S/RES/1244 (1999)',
#  'Slovakia',
#  'Slovenia',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'The former Yugoslav Rep. of Macedonia',
#  'Turkey',
#  'USA (EOIR)',
#  'USA (INS/DHS)',
#  'United Kingdom of Great Britain and Northern Ireland']

# %%
columns = ['Year', 'Month', "Country", "refugees", "totalcost"] + list(year_agg['category'].unique())
result_data = ref_data_agg.copy(deep=True)
result_data.columns = columns[:4]
result_data
# for c in columns[4:]:
#     result_data[c] = 0

# for idx, row in result_data.iterrows():
#     y, m, c = row[:3]
#     country_y_cost = year_agg[(year_agg.recipient == c)]
#     print(country_y_cost)
#     break
# Out:
#       Year  Month                                            Country  refugees
# 0     1999      1                                          Australia     574.0
# 1     1999      1                                            Austria    1366.0
# 2     1999      1                                            Belgium    1956.0
# 3     1999      1                                           Bulgaria      81.0
# 4     1999      1                                             Canada    2209.0
# 5     1999      1                                         Czech Rep.     602.0
# 6     1999      1                                            Denmark     675.0
# 7     1999      1                                            Finland     101.0
# 8     1999      1                                             France    1760.0
# 9     1999      1                                            Germany    8216.0
# 10    1999      1                                             Greece     167.0
# 11    1999      1                                            Hungary     907.0
# 12    1999      1                                            Ireland     234.0
# 13    1999      1                                      Liechtenstein      73.0
# 14    1999      1                                         Luxembourg     241.0
# 15    1999      1                                        Netherlands    3556.0
# 16    1999      1                                             Norway     548.0
# 17    1999      1                                             Poland     226.0
# 18    1999      1                                           Portugal      34.0
# 19    1999      1                                            Romania      21.0
# 20    1999      1                                           Slovakia      54.0
# 21    1999      1                                           Slovenia      40.0
# 22    1999      1                                              Spain     664.0
# 23    1999      1                                             Sweden     942.0
# 24    1999      1                                        Switzerland    3953.0
# 25    1999      1                                             Turkey     514.0
# 26    1999      1                                         USA (EOIR)     863.0
# 27    1999      1  United Kingdom of Great Britain and Northern I...    4710.0
# 28    1999      2                                          Australia     681.0
# 29    1999      2                                            Austria    1150.0
# ...    ...    ...                                                ...       ...
# 8804  2017     11                                         Czech Rep.      92.0
# 8805  2017     11                                            Denmark     272.0
# 8806  2017     11                                            Estonia      10.0
# 8807  2017     11                                             France    8013.0
# 8808  2017     11                                            Germany   18078.0
# 8809  2017     11                                            Iceland      92.0
# 8810  2017     11                                            Ireland     209.0
# 8811  2017     11                                              Italy   13517.0
# 8812  2017     11                                              Japan    1462.0
# 8813  2017     11                                             Latvia      61.0
# 8814  2017     11                                          Lithuania      35.0
# 8815  2017     11                                         Luxembourg     223.0
# 8816  2017     11                                              Malta     161.0
# 8817  2017     11                                         Montenegro      38.0
# 8818  2017     11                                        Netherlands    1217.0
# 8819  2017     11                                        New Zealand      49.0
# 8820  2017     11                                             Norway     396.0
# 8821  2017     11                                             Poland     324.0
# 8822  2017     11                                      Rep. of Korea     786.0
# 8823  2017     11                                            Romania     402.0
# 8824  2017     11               Serbia and Kosovo: S/RES/1244 (1999)      25.0
# 8825  2017     11                                           Slovakia      18.0
# 8826  2017     11                                           Slovenia     130.0
# 8827  2017     11                                              Spain    2525.0
# 8828  2017     11                                             Sweden    1536.0
# 8829  2017     11                                        Switzerland    1501.0
# 8830  2017     11              The former Yugoslav Rep. of Macedonia      24.0
# 8831  2017     11                                             Turkey    9504.0
# 8832  2017     11                                      USA (INS/DHS)   16403.0
# 8833  2017     11  United Kingdom of Great Britain and Northern I...    3160.0
#
# [8834 rows x 4 columns]

# %%
year_agg = year_agg.rename(columns={'recipient': 'country', 'date': 'year'})
result_data = result_data.rename(columns={'Country': 'country', 'Year': 'year'})

final_costs = pd.merge(result_data,year_agg, on=['year', 'country'])
final_costs.to_csv("distribution_data_v1.csv", index=False)
